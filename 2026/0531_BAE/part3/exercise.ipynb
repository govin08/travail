# %%
import pandas as pd
df = pd.DataFrame({
    '전': [6.1, 5.9, 6.3, 5.5, 6.0, 5.8, 6.2, 5.7, 6.1, 5.6],
    '후': [6.8, 6.5, 7.1, 6.0, 6.7, 6.3, 7.0, 6.4, 6.9, 6.2]
})

# %%
from scipy import stats
t, p = stats.ttest_rel(df['전'],df['후'])
print(t,p)
# Out:
# -18.27272727272727 2.0108341943291707e-08

# %%
import pandas as pd
df = pd.DataFrame({
    'A반': [82, 85, 78, 88, 90, 83, 87, 79, 84, 86],
    'B반': [75, 80, 77, 79, 82, 76, 81, 78, 80, 74]
})

# %%
t,p = stats.ttest_ind(df['A반'], df['B반'])
print(round(t,3))
print(round(p,3))
# Out:
# 4.074
# 0.001

# %%
import pandas as pd
df = pd.DataFrame({
    'advertising': [10, 15, 20, 25, 30, 35, 40, 45, 50, 55],
    'visitors':    [100, 120, 140, 170, 180, 210, 230, 240, 270, 290],
    'sales':       [200, 250, 300, 380, 420, 480, 540, 580, 650, 710]
})

# %%
import statsmodels.api as sm
X = df[['advertising', 'visitors']]
y = df['sales']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(round(model.params, 3))
print(round(model.pvalues, 3))
print(round(model.rsquared, 3))
# model.params
# Out:
# const         -4.0
# advertising    5.0
# visitors       1.5
# dtype: float64
# const          0.853
# advertising    0.012
# visitors       0.004
# dtype: float64
# 0.999

# %%
import pandas as pd
df = pd.DataFrame({
    'area':  [50, 65, 80, 95, 110, 125, 140, 70, 85, 100, 115, 60],
    'rooms': [1, 2, 2, 3, 3, 4, 4, 2, 2, 3, 3, 1],
    'age':   [10, 5, 15, 3, 8, 2, 1, 20, 12, 6, 4, 18],
    'price': [150, 220, 240, 350, 400, 470, 530, 200, 270, 360, 420, 180]
})

# %%
import statsmodels.api as sm
X = df[['area', 'rooms', 'age']]
y = df['price']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(round(model.params.area,3))
print(round(model.pvalues.age,3))
print(round(model.rsquared,3))
# Out:
# 3.958
# 0.002
# 0.996

# %%
# Out:
# 3.958

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     720.2
# Date:                Wed, 17 Jun 2026   Prob (F-statistic):           4.55e-10
# Time:                        13:46:59   Log-Likelihood:                -40.661
# No. Observations:                  12   AIC:                             89.32
# Df Residuals:                       8   BIC:                             91.26
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -18.8578     16.110     -1.171      0.275     -56.007      18.292
# ...
