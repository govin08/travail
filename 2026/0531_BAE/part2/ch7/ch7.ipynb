# %%
# sec 01

# %%
import pandas as pd

train = pd.read_csv('score_train.csv')
test = pd.read_csv('score_test.csv')

# %%
train.shape, test.shape
# Out:
# ((4198, 21), (1499, 20))

# %%
set(train.columns) - set(test.columns)
# Out:
# {'Credit_Score'}

# %%
target = train.pop('Credit_Score')
train.shape, test.shape
# Out:
# ((4198, 20), (1499, 20))

# %%
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Num_Credit_Inquiries        0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Credit_Mix                  0
# Payment_Behaviour           0
# Age                         0
# Annual_Income               0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Monthly_Inhand_Salary       0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Total_EMI_per_month         0
# dtype: int64
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Num_Credit_Inquiries        0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Credit_Mix                  0
# Payment_Behaviour           0
# Age                         0
# Annual_Income               0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Monthly_Inhand_Salary       0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Total_EMI_per_month         0
# dtype: int64

# %%
target.value_counts()
# Out:
# Credit_Score
# Standard    2225
# Poor        1232
# Good         741
# Name: count, dtype: int64

# %%
# train.info()
cols = train.select_dtypes('object').columns
cols
# Out:
# Index(['Payment_of_Min_Amount', 'Credit_Mix', 'Payment_Behaviour'], dtype='object')

# %%
for col in cols:
    print(col)
    print(train[col].value_counts())
    print()
# Out:
# Payment_of_Min_Amount
# Payment_of_Min_Amount
# Yes    2234
# No     1458
# NM      506
# Name: count, dtype: int64
#
# Credit_Mix
# Credit_Mix
# Standard    1967
# Good        1230
# Bad         1001
# Name: count, dtype: int64
#
# Payment_Behaviour
# Payment_Behaviour
# Low_spent_Small_value_payments      1415
# High_spent_Medium_value_payments    1115
# High_spent_Large_value_payments      708
# Low_spent_Medium_value_payments      450
# High_spent_Small_value_payments      270
# Low_spent_Large_value_payments       240
# Name: count, dtype: int64

# %%
print(train.shape, test.shape)
train = pd.get_dummies(train)
test  = pd.get_dummies(test)
print(train.shape, test.shape)
# Out:
# (4198, 20) (1499, 20)
# (4198, 29) (1499, 29)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.2, random_state=0)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (3358, 29) (840, 29) (3358,) (840,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(y_pred, y_val)
f1 = f1_score(y_pred, y_val, average='weighted')
print(f'accuracy : {accuracy:.3f}')
print(f'f1 : {f1:.3f}')
# Out:
# accuracy : 0.705
# f1 : 0.705

# %%
pred = rf.predict(test)
submit = pd.DataFrame({'pred':pred})
submit.to_csv('result1.csv', index=False)

# %%
# sec 02

# %%
train = pd.read_csv('drug_train.csv')
test  = pd.read_csv('drug_test.csv')
train.shape, test.shape
# Out:
# ((100, 6), (100, 5))

# %%
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# dtype: int64

# %%
print(set(train.columns) - set(test.columns))
# Out:
# {'Drug'}

# %%
train.Drug.value_counts()
# Out:
# Drug
# DrugY    41
# drugX    34
# drugA    13
# drugB     8
# drugC     4
# Name: count, dtype: int64

# %%
print(train.shape, test.shape)
target = train.pop('Drug')
train = pd.get_dummies(train)
test = pd.get_dummies(test)
print(train.shape, test.shape)
# Out:
# (100, 6) (100, 5)
# (100, 9) (100, 9)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.2, random_state=0)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (80, 9) (20, 9) (80,) (20,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(y_pred, y_val)
f1 = f1_score(y_pred, y_val, average='weighted')
print(f"accuracy : {accuracy:.3f}")
print(f"f1 : {f1:.3f}")
# Out:
# accuracy : 1.000
# f1 : 1.000

# %%
pred = rf.predict(test)
submit = pd.DataFrame({'pred':pred})
submit.to_csv('result2.csv')

# %%
# sec 03

# %%
train = pd.read_csv('glass_train.csv')
test = pd.read_csv('glass_test.csv')
print(train.shape, test.shape)
# Out:
# (149, 10) (65, 9)

# %%
set(train.columns) - set(test.columns)
# Out:
# {'Type'}

# %%
target = train.pop('Type')
print(train.shape, test.shape)
# Out:
# (149, 9) (65, 9)

# %%
target.value_counts()
# Out:
# Type
# 2    53
# 1    49
# 7    23
# 3     9
# 5     8
# 6     7
# Name: count, dtype: int64

# %%
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# RI    0
# Na    0
# Mg    0
# Al    0
# Si    0
# K     0
# Ca    0
# Ba    0
# Fe    0
# dtype: int64
# RI    0
# Na    0
# Mg    0
# Al    0
# Si    0
# K     0
# Ca    0
# Ba    0
# Fe    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.2, random_state=0)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (119, 9) (30, 9) (119,) (30,)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(y_pred, y_val)
f1 = f1_score(y_pred, y_val, average = 'weighted')
print(f'accuracy : {accuracy:.3f}')
print(f'f1 : {f1:.3f}')
# Out:
# accuracy : 0.667
# f1 : 0.683

# %%
pred =
