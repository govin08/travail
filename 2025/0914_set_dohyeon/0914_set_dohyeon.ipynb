# %% [markdown]
# # 1. 리스트

# %%
LA = ['a', 'b', 'c']
LB = ['a', 'c', 'b']
LC = ['a', 'b', 'b', 'c']
print(LA)
print(LB)
print(LC)
# Out:
# ['a', 'b', 'c']
# ['a', 'c', 'b']
# ['a', 'b', 'b', 'c']

# %%
print(LA==LB)
print(LA==LC)
print(LA[0])
# Out:
# False
# False
# a

# %%
LA.append('p')
print(LA)
# print(sorted(LB))
# Out:
# ['a', 'b', 'c', 'p']

# %% [markdown]
# # 2. 집합

# %%
SA = {'a', 'b', 'c'}
SB = {'a', 'c', 'b'}
SC = {'a', 'b', 'b', 'c'}
print(SA)
print(SB)
print(SC)
# Out:
# {'c', 'b', 'a'}
# {'c', 'b', 'a'}
# {'c', 'b', 'a'}

# %%
print(SA==SB)
print(SA==SC)
print(SA[0])
# Out:
# True
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 print(SA==SB)
#       2 print(SA==SC)
# ----> 3 print(SA[0])
#
# TypeError: 'set' object is not subscriptable

# %%
SA.add('p')
print(SA)
print(SA[0])
# print(sorted(SB))
# Out:
# {'c', 'p', 'a', 'b'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 SA.add('p')
#       2 print(SA)
# ----> 3 print(SA[0])
#       4 # print(sorted(SB))
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # 3. 벤 다이어그램

# %%
from matplotlib_venn import venn2
SA = {'a', 'b', 'c'}
SD = {'a', 'b', 'd', 'e'}

v = venn2([SA, SD], ('Set A', 'Set D'))

# %%
from matplotlib_venn import venn2
SA = {'a', 'b', 'c'}
SD = {'a', 'b', 'd', 'e'}

only_A = SA - SD           # A에만 있는 원소
only_D = SD - SA           # D에만 있는 원소  
both = SA & SD             # 교집합 원소

v = venn2([SA, SD], ('Set A', 'Set D'))

# 자동으로 원소 표시
v.get_label_by_id('10').set_text(', '.join(sorted(only_A)))
v.get_label_by_id('01').set_text(', '.join(sorted(only_D)))
v.get_label_by_id('11').set_text(', '.join(sorted(both)))
